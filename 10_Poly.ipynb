# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.uniform(-3, 3, size = 100)
X = x.reshape(-1, 1)
y = x**2 + x + 2 + np.random.normal(0, 1, 100)

# %%
plt.scatter(X, y)

# %%
# 引进我们这个多项式回归的类
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
poly.fit(X)
x2 = poly.transform(X)

# %%
x2[:5]
# Out:
# array([[ 1.        , -1.56247293,  2.44132165],
#        [ 1.        ,  0.14023296,  0.01966528],
#        [ 1.        , -0.05592009,  0.00312706],
#        [ 1.        ,  0.79088867,  0.62550489],
#        [ 1.        , -0.57696329,  0.33288663]])

# %%
y[:20]
# Out:
# array([2.93479702, 3.23293233, 2.04936937, 3.7769743 , 1.84124577,
#        1.90587052, 2.90110914, 1.28836804, 4.92664364, 0.88981403,
#        0.68964772, 6.74220593, 4.34804051, 9.21768088, 3.31005741,
#        2.06217559, 6.26520498, 5.86445325, 5.86875548, 2.93250895])

# %%
from sklearn.linear_model import LinearRegression
line_reg = LinearRegression()
line_reg.fit(x2, y)
y_predict = line_reg.predict(x2)
y_predict[:20]
# Out:
# array([ 2.97002111,  2.27483568,  2.06234011,  3.5252125 ,  1.86786686,
#         2.6136334 ,  2.46456356,  1.95904159,  3.69154404,  2.19607688,
#         1.90238671,  6.71070753,  5.2153513 , 10.19158631,  2.80901785,
#         1.89890086,  6.96155614,  5.69388722,  3.75056905,  1.87343346])

# %%
plt.scatter(x, y)
plt.plot(np.sort(x), y_predict[np.argsort(x)], color='r')
plt.show()
